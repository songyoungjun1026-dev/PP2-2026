# %% [markdown]
# ## typehint 연습
# 이 파일은 파이썬의 typehint 예재와 이론을 실습한 결과입니다.
# 작성자 : 202611825 송영준

# %% [markdown]
# 타입힌트는 함수의 매개변수와 반환값에 타입을 지정하는 목적으로 사용한며, 엄격한 타입지정으로 인한 프로그래머 의도를 명확하게 전달하기 위함이다, 안써도 되지만 파이썬 13부터는 쓰는 것을 권장하고 있다.

# %%
def greet(msg : str) -> None:
    print("in greet:", msg)
    return msg + "!"

print(greet("안녕"))
greet(3.141592)
